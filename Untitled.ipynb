# %%
import requests
from bs4 import BeautifulSoup as Bs
import yaml
import os
from settings import *

# %%
URL = input("Veuillez coller l'URL à scrapper : ")
print(URL)
largest_file = ""
largest_number = -1
folder_path = os.path.join(os.getcwd(), "images")
nom_dossier = URL.strip("/").split("/")[-1]
print(nom_dossier)
nom_complet = str(folder_path)+"/"+str(nom_dossier)
print(nom_complet)
if not os.path.exists(nom_complet):
    os.mkdir(f'{folder_path}/{nom_dossier}')
    print(f"Le dossier '{nom_dossier}' a été créé avec succès.")
else:
    print(f"Le dossier '{nom_dossier}' existe déjà.")
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".jpeg"):  # Filtrer les fichiers d'extension .jpg ou .jpeg
        file_path = os.path.join(folder_path, filename)

        # Extraire le numéro de fichier du nom
        file_number = int(filename.replace("image_", "").replace(".jpg", "").replace(".jpeg", ""))

        if file_number > largest_number:
            largest_number = file_number
            largest_file = filename
if largest_file == "":
    indicefile = 1
else:
    indicefile = largest_file.split("_")[1]
    indicefile = indicefile.split(".")[0]
    indicefile = int(indicefile)
print(indicefile)
# Out:
# https://fapello.com/alice-delish/
# alice-delish
# C:\Users\ASUS\PycharmProjects\pythonProject4\images/alice-delish
# Le dossier 'alice-delish' existe déjà.
# 9

# %%
for i in range(indicefile,int(indicefile)+NBFILES):
    with open("headers.yml") as f_headers:
        browser_headers = yaml.safe_load(f_headers)
    url = f"{URL}/{i}"
    headers = browser_headers["Chrome"]
    response = requests.get(url, headers=headers)
    html = response.text
    soup = Bs(html,'html.parser')
    images_url = soup.find_all('img')
    alt_img =''
    imagebool = False
    index = IMAGE_INDEX
    while not imagebool and index >= 0:
        try:
            alt_img = images_url[index]['src']
            img_data = requests.get(alt_img).content
            image_size = len(img_data)
            size = 10000
            if image_size >= size:
                imagebool = True
            else:
                print(f"L'image n°{i} est inférieure à {size/1000}")
                index -= 1
        except:
            break
    if imagebool == True:
        img_data = requests.get(alt_img).content
        filename = f'{nom_complet}/image_{i}.jpg'
        with open(filename, 'wb') as file:
            file.write(img_data)
        print(f"L'image n°{i} a été téléchargée avec succès.")
    else:
        print(f"L'image n'a pas été téléchargée, image suivante n°{i+1}")
# Out:
# L'image n°9 est inférieure à 10.0
# L'image n°9 a été téléchargée avec succès.
# L'image n°10 a été téléchargée avec succès.
# L'image n°11 est inférieure à 10.0
# L'image n°11 a été téléchargée avec succès.
# L'image n°12 a été téléchargée avec succès.
# L'image n°13 a été téléchargée avec succès.
# L'image n°14 est inférieure à 10.0
# L'image n°14 est inférieure à 10.0
# L'image n°14 a été téléchargée avec succès.
# L'image n°15 a été téléchargée avec succès.
# L'image n°16 est inférieure à 10.0
# L'image n°16 a été téléchargée avec succès.
# L'image n°17 a été téléchargée avec succès.
# L'image n°18 a été téléchargée avec succès.
# L'image n°19 est inférieure à 10.0
# L'image n°19 a été téléchargée avec succès.
# L'image n°20 a été téléchargée avec succès.
# L'image n°21 est inférieure à 10.0
# L'image n°21 a été téléchargée avec succès.
# L'image n°22 a été téléchargée avec succès.
# L'image n°23 a été téléchargée avec succès.
# L'image n°24 a été téléchargée avec succès.
# L'image n°25 a été téléchargée avec succès.
# L'image n°26 est inférieure à 10.0
# L'image n°26 a été téléchargée avec succès.
# L'image n°27 a été téléchargée avec succès.
# L'image n°28 a été téléchargée avec succès.
# L'image n°29 a été téléchargée avec succès.
# L'image n°30 a été téléchargée avec succès.
# L'image n°31 a été téléchargée avec succès.
# L'image n°32 est inférieure à 10.0
# L'image n°32 a été téléchargée avec succès.
# L'image n°33 est inférieure à 10.0
# L'image n°33 a été téléchargée avec succès.
# L'image n°34 a été téléchargée avec succès.
# L'image n°35 a été téléchargée avec succès.
# L'image n°36 est inférieure à 10.0
# L'image n°36 est inférieure à 10.0
# L'image n°36 a été téléchargée avec succès.
# L'image n°37 a été téléchargée avec succès.
# L'image n°38 a été téléchargée avec succès.
# L'image n°39 est inférieure à 10.0
# L'image n°39 est inférieure à 10.0
# L'image n°39 est inférieure à 10.0
# L'image n°39 a été téléchargée avec succès.
# L'image n°40 a été téléchargée avec succès.
# L'image n°41 est inférieure à 10.0
# L'image n°41 a été téléchargée avec succès.
# L'image n°42 est inférieure à 10.0
# L'image n°42 est inférieure à 10.0
# L'image n°42 est inférieure à 10.0
# L'image n°42 est inférieure à 10.0
# L'image n°42 a été téléchargée avec succès.
# L'image n°43 a été téléchargée avec succès.
# L'image n°44 est inférieure à 10.0
# L'image n°44 a été téléchargée avec succès.
# L'image n°45 a été téléchargée avec succès.
# L'image n°46 a été téléchargée avec succès.
# L'image n°47 a été téléchargée avec succès.
# L'image n°48 a été téléchargée avec succès.
# L'image n°49 est inférieure à 10.0
# L'image n°49 a été téléchargée avec succès.
# L'image n°50 est inférieure à 10.0
# L'image n°50 a été téléchargée avec succès.
# L'image n°51 a été téléchargée avec succès.
# L'image n°52 a été téléchargée avec succès.
# L'image n°53 a été téléchargée avec succès.
# L'image n°54 est inférieure à 10.0
# L'image n°54 a été téléchargée avec succès.
# L'image n°55 a été téléchargée avec succès.
# L'image n°56 a été téléchargée avec succès.
# L'image n°57 a été téléchargée avec succès.
# L'image n°58 a été téléchargée avec succès.
# L'image n°59 a été téléchargée avec succès.
# L'image n°60 est inférieure à 10.0
# L'image n°60 est inférieure à 10.0
# L'image n°60 a été téléchargée avec succès.
# L'image n°61 a été téléchargée avec succès.
# L'image n°62 a été téléchargée avec succès.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 27
#      25         break
#      26 if imagebool == True:
# ---> 27     img_data = requests.get(alt_img).content
#      28     filename = f'{nom_complet}/image_{i}.jpg'
#      29     with open(filename, 'wb') as file:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:
